# %% [markdown]
# # Coursera Capstone Project Work

# %% [markdown]
# *This notebook will mainly be used for the project work under capstone module of IBM Data Science Professional Certification.*

# %% [markdown]
# **Work Done & Submitted by Mohit Khandelwal**

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
